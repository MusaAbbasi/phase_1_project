# %%
import pandas as pd
import sqlite3

# %%
rt_reviews_df = pd.read_csv('zippedData/rt.reviews.tsv.gz',delimiter='\t',encoding='windows-1252')
rt_reviews_df
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
rt_df = pd.read_csv('zippedData/rt.movie_info.tsv.gz',delimiter='\t',encoding='windows-1252')
rt_df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
rt_movies_df = rt_reviews_df.merge(rt_df, on = "id", how = "left")
rt_movies_df
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 1         3  It's an allegory in search of a meaning that n...      NaN
# 2         3  ... life lived in a bubble in financial dealin...      NaN
# 3         3  Continuing along a line introduced in last yea...      NaN
# 4         3             ... a perverse twist on neorealism...       NaN
# ...     ...                                                ...      ...
# 54427  2000  The real charm of this trifle is the deadpan c...      NaN
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic         publisher  \
# ...

# %%
rt_movies_df['genre'] = rt_movies_df['genre'].str.split("|")
rt_movies_df
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 1         3  It's an allegory in search of a meaning that n...      NaN
# 2         3  ... life lived in a bubble in financial dealin...      NaN
# 3         3  Continuing along a line introduced in last yea...      NaN
# 4         3             ... a perverse twist on neorealism...       NaN
# ...     ...                                                ...      ...
# 54427  2000  The real charm of this trifle is the deadpan c...      NaN
# 54428  2000                                                NaN      1/5
# 54429  2000                                                NaN      2/5
# 54430  2000                                                NaN    2.5/5
# 54431  2000                                                NaN      3/5
#
#         fresh             critic  top_critic         publisher  \
# ...

# %%
rt_movies_df = rt_movies_df.explode("genre")
rt_movies_df
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 1         3  It's an allegory in search of a meaning that n...      NaN
# 1         3  It's an allegory in search of a meaning that n...      NaN
# 2         3  ... life lived in a bubble in financial dealin...      NaN
# ...     ...                                                ...      ...
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
#
#         fresh           critic  top_critic         publisher  \
# ...

# %%
#rt_movies_df['rating_x'] = rt_movies_df['rating_x'].str.slice(stop = 1)
#rt_movies_df

# %%
rt_movies_df = rt_movies_df.dropna(subset = ["rating_x"])

# %%
rt_movies_df['rating_x'].value_counts()
# Out:
# 3/5       9722
# 4/5       8229
# 3/4       8033
# 2/5       6990
# 2/4       5828
#           ...
# 2.3/4        1
# 3.1/5        1
# 3.1          1
# 4.0/10       1
# 3/2          1
# Name: rating_x, Length: 186, dtype: int64

# %%
rt_movies_df
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 6         3  Quickly grows repetitive and tiresome, meander...        C
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# ...     ...                                                ...      ...
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
#
#         fresh           critic  top_critic           publisher  \
# ...

# %%
rt_movies_df['rating_x'].unique()
# Out:
# array(['3/5', 'C', '2/5', 'B-', '2/4', 'B', '3/4', '4/5', '4/4', '6/10',
#        '1/4', '8', '2.5/4', '4/10', '2.0/5', '3/10', '7/10', 'A-', '5/5',
#        'F', '3.5/4', 'D+', '1.5/4', '3.5/5', '8/10', 'B+', '9/10',
#        '2.5/5', '7.5/10', '5.5/10', 'C-', '1.5/5', '1/5', '5/10', 'C+',
#        '0/5', '6', '0.5/4', 'D', '3.1/5', '3/6', '4.5/5', '0/4', '2/10',
#        'D-', '7', '1/10', '3', 'A+', 'A', '4.0/4', '9.5/10', '2.5',
#        '2.1/2', '6.5/10', '3.7/5', '8.4/10', '9', '1', '7.2/10', '2.2/5',
#        '0.5/10', '5', '0', '2', '4.5', '7.7', '5.0/5', '8.5/10', '3.0/5',
#        '0.5/5', '1.5/10', '3.0/4', '2.3/10', '4.5/10', '4/6', '3.5',
#        '8.6/10', '6/8', '2.0/4', '2.7', '4.2/10', '5.8', '4', '7.1/10',
#        '5/4', 'N', '3.5/10', '5.8/10', 'R', '4.0/5', '0/10', '5.0/10',
#        '5.9/10', '2.4/5', '1.9/5', '4.9', '7.4/10', '1.5', '2.3/4',
#        '8.8/10', '4.0/10', '2.2', '3.8/10', '6.8/10', '7.3', '7.0/10',
# ...

# %%
rt_movies_df.groupby('rating_x').count()
# Out:
#            id  review  fresh  critic  top_critic  publisher  date  synopsis  \
# rating_x
# 0          16      13     16      16          16         16    16        16
# 0.5/10      3       3      3       3           3          3     3         3
# 0.5/4     186     170    186     186         186        186   186       186
# 0.5/5     114      86    114      79         114        114   114       114
# 0/10        7       7      7       7           7          7     7         7
# ...       ...     ...    ...     ...         ...        ...   ...       ...
# F+          3       3      3       3           3          3     3         3
# F-          3       3      3       3           3          3     3         3
# N           3       3      3       3           3          0     3         3
# R           7       7      7       7           7          0     7         7
# T           2       2      2       2           2          2     2         2
#
# ...

# %%
rt_movies_df.head(6)
# Out:
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 6   3  Quickly grows repetitive and tiresome, meander...        C  rotten
# 6   3  Quickly grows repetitive and tiresome, meander...        C  rotten
# 7   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
# 7   3  Cronenberg is not a director to be daunted by ...      2/5  rotten
#
#            critic  top_critic           publisher               date  \
# 0      PJ Nabarro           0     Patrick Nabarro  November 10, 2018
# 0      PJ Nabarro           0     Patrick Nabarro  November 10, 2018
# 6  Eric D. Snider           0     EricDSnider.com      July 17, 2013
# 6  Eric D. Snider           0     EricDSnider.com      July 17, 2013
# 7    Matt Kelemen           0  Las Vegas CityLife     April 21, 2013
# ...

# %%
newdf1 = rt_movies_df[rt_movies_df["rating_x"].str.contains('/')]
newdf1
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
#
#         fresh           critic  top_critic           publisher  \
# ...

# %%
newdf1.groupby('rating_x').count()
# Out:
#            id  review  fresh  critic  top_critic  publisher  date  synopsis  \
# rating_x
# 0.5/10      3       3      3       3           3          3     3         3
# 0.5/4     186     170    186     186         186        186   186       186
# 0.5/5     114      86    114      79         114        114   114       114
# 0/10        7       7      7       7           7          7     7         7
# 0/4       265     240    265     254         265        265   265       265
# ...       ...     ...    ...     ...         ...        ...   ...       ...
# 9.0/10      2       2      2       2           2          2     2         2
# 9.2/10      4       4      4       4           4          3     4         4
# 9.5/10     30      30     30      27          30         29    30        30
# 9.6/10      1       1      1       1           1          1     1         1
# 9/10      693     638    693     658         693        682   693       693
#
# ...

# %%
newdf1
# Out:
#          id                                             review rating_x  \
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 0         3  A distinctly gallows take on contemporary fina...      3/5
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 7         3  Cronenberg is not a director to be daunted by ...      2/5
# 12        3  Robert Pattinson works mighty hard to make Cos...      2/4
# ...     ...                                                ...      ...
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
# 54431  2000                                                NaN      3/5
#
#         fresh           critic  top_critic           publisher  \
# ...

# %%
newdf1['rating_x']
# Out:
# 0       NaN
# 0       NaN
# 7       NaN
# 7       NaN
# 12      NaN
#          ..
# 54431   NaN
# 54431   NaN
# 54431   NaN
# 54431   NaN
# 54431   NaN
# Name: rating_x, Length: 74563, dtype: float64

# %%
newdf1 = newdf1.loc[]
